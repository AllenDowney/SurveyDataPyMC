# %% [markdown]
# # Title
#
#
# If you are not familiar with PyMC, you can [start with this chapter from *Think Bayes*](https://allendowney.github.io/ThinkBayes2/chap19.html), especially the World Cup Problem. Or you can [run that chapter on Colab](https://colab.research.google.com/github/AllenDowney/ThinkBayes2/blob/master/notebooks/chap19_v3.ipynb).
#
# You can read [the slides I used to present this example](COMING SOON).

# %% [markdown]
# [Click here to run this notebook on Colab](https://colab.research.google.com/github/AllenDowney/SurveyDataPyMC/blob/main/notebooks/01_tutorial.ipynb)

# %%
# Get utils.py

from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)
        
download('https://github.com/AllenDowney/SurveyDataPyMC/raw/main/notebooks/utils.py')

# %%
try:
    import empiricaldist
except ImportError:
    # !pip install empiricaldist

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm

from utils import decorate, value_counts

# %%
# Make the figures smaller to save some screen real estate

plt.rcParams['figure.dpi'] = 75
plt.rcParams['figure.figsize'] = [6, 3.5]
plt.rcParams['axes.titlelocation'] = 'left'

# %%
# Get the GSS data

# This dataset is prepared in GssExtract/notebooks/02_make_extract-2022_3a.ipynb

DATA_PATH = "https://github.com/AllenDowney/GssExtract/raw/main/data/interim/"
filename = "gss_extract_2022_3a.hdf"
download(DATA_PATH + filename)

# %%
gss = pd.read_hdf(filename, "gss")
gss.shape
# Out:
# (72390, 57)

# %%
# https://gssdataexplorer.norc.org/variables/452/vshow

question = """Taken all together, how would you say things are these days--
would you say that you are very happy, pretty happy, or not too happy?
"""

# 1 = very happy
# 2 = pretty happy
# 3 = not too happy

title = "Are you happy?"
subtitle = "Percent saying very happy"
ylim = [10, 45]

# %%
value_counts(gss['happy'])
# Out:
#         counts
# values
# 1.0      21550
# 2.0      37446
# 3.0       8681
# NaN       4713

# %%
missing = gss['happy'].isna()
gss['y1'] = (gss['happy'] == 1).astype(float).mask(missing)
gss['y2'] = (gss['happy'] == 2).astype(float).mask(missing)
gss['y3'] = (gss['happy'] == 3).astype(float).mask(missing)
value_counts(gss['y1'])
# Out:
#         counts
# values
# 0.0      46127
# 1.0      21550
# NaN       4713

# %%
# shift so the codes are 0, 1, 2
data = gss['happy'].values - 1
pd.Series(data).value_counts().sort_index()
# Out:
# 0.0    21550
# 1.0    37446
# 2.0     8681
# Name: count, dtype: int64

# %%
gss['cohort'].describe()
# Out:
# count    71987.000000
# mean      1991.908095
# std        561.717010
# min       1883.000000
# 25%       1938.000000
# 50%       1954.000000
# 75%       1968.000000
# max       9999.000000
# Name: cohort, dtype: float64

# %%
bins = [1928, 1946, 1965, 1981, 1997, 2013, 2025] 
labels = ['Silent', 'Boomer', 'GenX', 'Millennial', 'GenZ', 'Alpha']

# Assign each cohort to a generation
gss['generation'] = pd.cut(gss['cohort'], bins=bins, labels=labels, right=False)

# %%
# gss_clean = gss.dropna(subset=['generation', 'sex', 'happy']).sample(10000)
gss_clean = gss.dropna(subset=['generation', 'sex', 'happy'])
gss_clean.shape
# Out:
# (56641, 61)

# %%
gss_clean['generation'].value_counts()
# Out:
# generation
# Boomer        24087
# Silent        13348
# GenX          12106
# Millennial     6049
# GenZ           1051
# Alpha             0
# Name: count, dtype: int64

# %%
pd.crosstab(gss_clean['year'], gss_clean['generation'])
# Out:
# generation  Silent  Boomer  GenX  Millennial  GenZ
# year
# 1972           484     310     0           0     0
# 1973           497     327     0           0     0
# 1974           432     374     0           0     0
# 1975           470     413     0           0     0
# 1976           476     431     0           0     0
# 1977           470     451     0           0     0
# 1978           444     554     0           0     0
# 1980           406     569     0           0     0
# 1982           491     805     0           0     0
# 1983           414     726    21           0     0
# 1984           387     663    43           0     0
# 1985           424     650    51           0     0
# 1986           391     620    85           0     0
# 1987           506     740   141           0     0
# 1988           345     643   177           0     0
# 1989           407     607   239           0     0
# 1990           323     571   218           0     0
# 1991           367     628   261           0     0
# 1993           376     653   327           0     0
# 1994           701    1314   544           0     0
# 1996           615    1176   818           0     0
# 1998           525    1197   818           0     0
# 2000           468    1211   817          77     0
# 2002           244     534   448          76     0
# 2004           227     485   398         137     0
# 2006           466    1070   952         409     0
# 2008           269     742   579         351     0
# 2010           296     646   608         427     0
# 2012           273     599   575         485     0
# 2014           303     844   718         632     0
# 2016           270     957   755         778    67
# 2018           194     647   650         701   139
# 2021           235    1040   923        1061   392
# 2022           152     890   940         915   453

# %%
# Convert generation to a categorical variable
generation = pd.Categorical(gss_clean['generation'], categories=labels)
generation_codes = generation.codes

# %%
years = gss_clean['year'].value_counts().sort_index()
year_labels = years.index.values

# %%
# Convert year to a categorical variable
year = pd.Categorical(gss_clean['year'], categories=year_labels)
year_codes = year.codes

# %%
# Independent variable (sex)
sex = gss_clean['sex'].values

# %%
# Dependent variable (happiness levels)
y = gss_clean['happy'].values - 1
pd.Series(y).value_counts()
# Out:
# 1.0    31900
# 0.0    17384
# 2.0     7357
# Name: count, dtype: int64

# %% [markdown]
# ## Model 1

# %%
# Build the model
with pm.Model() as ordered_logistic_model1:
    
    # Priors for the coefficients
    intercept = pm.Normal('intercept', mu=0, sigma=2)
    beta_sex = pm.Normal('beta_sex', mu=0, sigma=2)
    
    # Priors for the generation coefficients (one per generation)
    beta_gen = pm.Normal('beta_gen', mu=0, sigma=2, shape=len(labels))
    
    # Priors for the cutpoints (thresholds) between categories
    cutpoints = pm.Normal('cutpoints', mu=np.array([-1, 1]), sigma=2, shape=2,
                          transform=pm.distributions.transforms.ordered)
    
    # Linear combination of coefficients and independent variables
    eta = intercept + beta_sex * sex + beta_gen[generation_codes]
    
    # Likelihood: ordered logistic regression
    y_obs = pm.OrderedLogistic('y_obs', eta=eta, cutpoints=cutpoints, 
                               compute_p=False, observed=y)

# %%
with ordered_logistic_model1:
    idata = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [intercept, beta_sex, beta_gen, cutpoints]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[119], line 2
#       1 with ordered_logistic_model1:
# ----> 2     idata = pm.sample()
#
# File ~/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pymc/sampling/mcmc.py:871, in sample(draws, tune, chains, cores, random_seed, progressbar, progressbar_theme, step, var_names, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, blas_cores, model, **kwargs)
#     867 t_sampling = time.time() - t_start
#     869 # Packaging, validating and returning the result was extracted
#     870 # into a function to make it easier to test and refactor.
# --> 871 return _sample_return(
#     872     run=run,
#     873     traces=traces,
#     874     tune=tune,
#     875     t_sampling=t_sampling,
#     876     discard_tuned_samples=discard_tuned_samples,
#     877     compute_convergence_checks=compute_convergence_checks,
#     878     return_inferencedata=return_inferencedata,
#     879     keep_warning_stat=keep_warning_stat,
#     880     idata_kwargs=idata_kwargs or {},
#     881     model=model,
#     882 )
#
# File ~/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pymc/sampling/mcmc.py:902, in _sample_return(run, traces, tune, t_sampling, discard_tuned_samples, compute_convergence_checks, return_inferencedata, keep_warning_stat, idata_kwargs, model)
#     900 # Pick and slice chains to keep the maximum number of samples
#     901 if discard_tuned_samples:
# --> 902     traces, length = _choose_chains(traces, tune)
#     903 else:
#     904     traces, length = _choose_chains(traces, 0)
#
# File ~/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pymc/backends/base.py:593, in _choose_chains(traces, tune)
#     591 lengths = [max(0, len(trace) - tune) for trace in traces]
#     592 if not sum(lengths):
# --> 593     raise ValueError("Not enough samples to build a trace.")
#     595 idxs = np.argsort(lengths)
#     596 l_sort = np.array(lengths)[idxs]
#
# ValueError: Not enough samples to build a trace.

# %%
pm.summary(idata)
# Out:
#                mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# intercept    -0.135  1.269  -2.368    2.341      0.038    0.030    1110.0
# beta_sex     -0.050  0.053  -0.147    0.050      0.001    0.001    1971.0
# beta_gen[0]  -0.523  0.877  -2.188    1.066      0.032    0.024     744.0
# beta_gen[1]  -0.377  0.877  -1.973    1.273      0.032    0.025     749.0
# beta_gen[2]  -0.249  0.876  -1.797    1.451      0.032    0.025     751.0
# beta_gen[3]  -0.125  0.878  -1.746    1.488      0.032    0.025     749.0
# beta_gen[4]   0.845  0.895  -0.854    2.462      0.032    0.023     786.0
# beta_gen[5]   0.075  1.954  -3.703    3.607      0.053    0.046    1368.0
# cutpoints[0] -1.334  1.177  -3.627    0.820      0.033    0.025    1250.0
# cutpoints[1]  1.420  1.177  -0.832    3.633      0.033    0.025    1250.0
#
#               ess_tail  r_hat
# intercept       1226.0   1.00
# beta_sex        1400.0   1.00
# beta_gen[0]      796.0   1.01
# beta_gen[1]      837.0   1.00
# beta_gen[2]      858.0   1.00
# beta_gen[3]      871.0   1.01
# beta_gen[4]      888.0   1.01
# beta_gen[5]     1087.0   1.00
# cutpoints[0]    1166.0   1.00
# cutpoints[1]    1209.0   1.00

# %%
import arviz as az

az.to_netcdf(idata, "ordered_logistic_model1.nc")
# Out:
# 'ordered_logistic_model_idata.nc'

# %%
# !ls -lh ordered_logistic_model1.nc
# Out:
# -rw-rw-r-- 1 downey downey 3.3M Aug 29 20:32 ordered_logistic_model_idata.nc

# %% [markdown]
# ## Model 2

# %%
# Build the model
with pm.Model() as ordered_logistic_model2:
    
    # Priors for the coefficients
    intercept = pm.Normal('intercept', mu=0, sigma=2)
    
    # Priors for the generation coefficients (one per generation)
    beta_gen = pm.Normal('beta_gen', mu=0, sigma=2, shape=len(labels))
    
    # Priors for the generation coefficients (one per generation)
    beta_year = pm.Normal('beta_year', mu=0, sigma=2, shape=len(year_labels))
    
    # Priors for the cutpoints (thresholds) between categories
    cutpoints = pm.Normal('cutpoints', mu=np.array([-1, 1]), sigma=2, shape=2,
                          transform=pm.distributions.transforms.ordered)
    
    # Linear combination of coefficients and independent variables
    eta = intercept + beta_year[year_codes] + beta_gen[generation_codes]
    
    # Likelihood: ordered logistic regression
    y_obs = pm.OrderedLogistic('y_obs', eta=eta, cutpoints=cutpoints, 
                               compute_p=False, observed=y)

# %%
with ordered_logistic_model2:
    idata = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [intercept, beta_gen, beta_year, cutpoints]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 2
#       1 with ordered_logistic_model2:
# ----> 2     idata = pm.sample()
#
# File ~/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pymc/sampling/mcmc.py:871, in sample(draws, tune, chains, cores, random_seed, progressbar, progressbar_theme, step, var_names, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, blas_cores, model, **kwargs)
#     867 t_sampling = time.time() - t_start
#     869 # Packaging, validating and returning the result was extracted
#     870 # into a function to make it easier to test and refactor.
# --> 871 return _sample_return(
#     872     run=run,
#     873     traces=traces,
#     874     tune=tune,
#     875     t_sampling=t_sampling,
#     876     discard_tuned_samples=discard_tuned_samples,
#     877     compute_convergence_checks=compute_convergence_checks,
#     878     return_inferencedata=return_inferencedata,
#     879     keep_warning_stat=keep_warning_stat,
#     880     idata_kwargs=idata_kwargs or {},
#     881     model=model,
#     882 )
#
# File ~/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pymc/sampling/mcmc.py:902, in _sample_return(run, traces, tune, t_sampling, discard_tuned_samples, compute_convergence_checks, return_inferencedata, keep_warning_stat, idata_kwargs, model)
#     900 # Pick and slice chains to keep the maximum number of samples
#     901 if discard_tuned_samples:
# --> 902     traces, length = _choose_chains(traces, tune)
#     903 else:
#     904     traces, length = _choose_chains(traces, 0)
#
# File ~/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pymc/backends/base.py:593, in _choose_chains(traces, tune)
#     591 lengths = [max(0, len(trace) - tune) for trace in traces]
#     592 if not sum(lengths):
# --> 593     raise ValueError("Not enough samples to build a trace.")
#     595 idxs = np.argsort(lengths)
#     596 l_sort = np.array(lengths)[idxs]
#
# ValueError: Not enough samples to build a trace.

# %%
pm.summary(idata)
# Out:
#                 mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# intercept     -0.149  1.245  -2.580    2.052      0.051    0.036     607.0
# beta_gen[0]   -0.469  0.868  -1.961    1.315      0.047    0.034     338.0
# beta_gen[1]   -0.330  0.866  -1.882    1.370      0.048    0.034     332.0
# beta_gen[2]   -0.171  0.866  -1.740    1.508      0.047    0.034     336.0
# beta_gen[3]   -0.107  0.870  -1.661    1.584      0.048    0.034     334.0
# beta_gen[4]    0.708  0.884  -1.044    2.293      0.047    0.034     348.0
# beta_gen[5]    0.009  1.984  -4.011    3.601      0.052    0.043    1490.0
# beta_year[0]   0.344  0.411  -0.357    1.168      0.037    0.026     122.0
# beta_year[1]  -0.221  0.397  -0.993    0.466      0.039    0.027     106.0
# beta_year[2]  -0.176  0.414  -0.947    0.575      0.035    0.025     142.0
# beta_year[3]   0.023  0.395  -0.708    0.759      0.039    0.027     106.0
# beta_year[4]  -0.364  0.400  -1.117    0.393      0.038    0.027     111.0
# beta_year[5]   0.039  0.388  -0.701    0.721      0.037    0.026     111.0
# beta_year[6]   0.036  0.402  -0.694    0.770      0.037    0.026     116.0
# beta_year[7]   0.094  0.387  -0.673    0.782      0.038    0.027     103.0
# beta_year[8]   0.369  0.378  -0.368    1.062      0.037    0.027     102.0
# beta_year[9]   0.598  0.378  -0.140    1.276      0.037    0.026     103.0
# beta_year[10]  0.304  0.389  -0.367    1.095      0.036    0.025     116.0
# beta_year[11]  0.123  0.380  -0.586    0.831      0.035    0.025     116.0
# beta_year[12] -0.244  0.385  -0.956    0.461      0.037    0.027     106.0
# beta_year[13]  0.152  0.372  -0.507    0.870      0.036    0.026     105.0
# beta_year[14] -0.607  0.379  -1.347    0.085      0.036    0.025     111.0
# beta_year[15]  0.004  0.379  -0.713    0.701      0.036    0.026     109.0
# beta_year[16] -0.119  0.377  -0.851    0.583      0.036    0.026     109.0
# beta_year[17] -0.116  0.379  -0.759    0.619      0.037    0.026     106.0
# beta_year[18]  0.192  0.373  -0.468    0.900      0.036    0.026     106.0
# beta_year[19] -0.042  0.351  -0.695    0.604      0.037    0.026      91.0
# beta_year[20]  0.007  0.349  -0.657    0.642      0.037    0.026      88.0
# beta_year[21]  0.025  0.353  -0.628    0.691      0.038    0.027      87.0
# beta_year[22] -0.044  0.358  -0.753    0.592      0.038    0.027      90.0
# beta_year[23] -0.133  0.369  -0.841    0.549      0.037    0.027      97.0
# beta_year[24] -0.030  0.369  -0.713    0.658      0.035    0.025     110.0
# beta_year[25] -0.167  0.353  -0.864    0.467      0.037    0.026      91.0
# beta_year[26]  0.077  0.366  -0.589    0.759      0.038    0.027      94.0
# beta_year[27]  0.043  0.357  -0.657    0.696      0.036    0.026      96.0
# beta_year[28] -0.321  0.359  -1.012    0.346      0.037    0.026      96.0
# beta_year[29] -0.070  0.352  -0.740    0.571      0.037    0.027      89.0
# beta_year[30]  0.046  0.352  -0.603    0.705      0.037    0.026      92.0
# beta_year[31] -0.217  0.358  -0.908    0.387      0.036    0.025      99.0
# beta_year[32]  0.535  0.355  -0.128    1.190      0.037    0.026      92.0
# beta_year[33]  0.126  0.353  -0.535    0.776      0.037    0.026      92.0
# cutpoints[0]  -1.213  1.175  -3.381    1.070      0.041    0.029     823.0
# cutpoints[1]   1.576  1.175  -0.562    3.872      0.041    0.029     826.0
#
#                ess_tail  r_hat
# intercept         999.0   1.00
# beta_gen[0]       665.0   1.01
# beta_gen[1]       663.0   1.01
# beta_gen[2]       688.0   1.01
# beta_gen[3]       612.0   1.01
# beta_gen[4]       684.0   1.00
# beta_gen[5]      1431.0   1.00
# beta_year[0]      497.0   1.03
# beta_year[1]      350.0   1.03
# beta_year[2]      393.0   1.03
# beta_year[3]      349.0   1.03
# beta_year[4]      399.0   1.03
# beta_year[5]      345.0   1.03
# beta_year[6]      370.0   1.03
# beta_year[7]      289.0   1.04
# beta_year[8]      359.0   1.04
# beta_year[9]      372.0   1.03
# beta_year[10]     385.0   1.03
# beta_year[11]     300.0   1.03
# beta_year[12]     379.0   1.03
# beta_year[13]     337.0   1.03
# beta_year[14]     398.0   1.03
# beta_year[15]     339.0   1.03
# beta_year[16]     361.0   1.03
# beta_year[17]     403.0   1.03
# beta_year[18]     338.0   1.03
# beta_year[19]     251.0   1.04
# beta_year[20]     227.0   1.04
# beta_year[21]     254.0   1.04
# beta_year[22]     222.0   1.04
# beta_year[23]     349.0   1.04
# beta_year[24]     285.0   1.03
# beta_year[25]     279.0   1.04
# beta_year[26]     303.0   1.04
# beta_year[27]     278.0   1.04
# beta_year[28]     372.0   1.04
# beta_year[29]     304.0   1.04
# beta_year[30]     248.0   1.04
# beta_year[31]     291.0   1.04
# beta_year[32]     290.0   1.04
# beta_year[33]     270.0   1.04
# cutpoints[0]     1025.0   1.00
# cutpoints[1]     1072.0   1.00

# %%
import arviz as az

az.to_netcdf(idata, "ordered_logistic_model2.nc")
# Out:
# 'ordered_logistic_model_idata.nc'

# %%
# !ls -lh ordered_logistic_model2.nc
# Out:
# -rw-rw-r-- 1 downey downey 3.3M Aug 29 20:32 ordered_logistic_model_idata.nc

# %% [markdown]
# ## Model 3
#
# With a different parameter for each year, generation pair

# %%
with pm.Model() as interaction_model:
    
    # Priors for the global intercept
    intercept = pm.Normal('intercept', mu=0, sigma=2)
    
    # Hyperpriors for the group-level means and standard deviations
    mu_gen_year = pm.Normal('mu_gen_year', mu=0, sigma=2)
    sigma_gen_year = pm.HalfNormal('sigma_gen_year', sigma=2)
    
    # Group-level effects with hierarchical structure: a coefficient for each year-generation combination
    beta_gen_year = pm.Normal('beta_gen_year', mu=mu_gen_year, sigma=sigma_gen_year, 
                              shape=(len(year_labels), len(generation_labels)))
    
    # Priors for the cutpoints (thresholds) between categories
    cutpoints = pm.Normal('cutpoints', mu=np.array([-1, 1]), sigma=2, shape=2,
                          transform=pm.distributions.transforms.ordered)
    
    # Linear combination of coefficients and independent variables
    eta = intercept + beta_gen_year[year_codes, generation_codes]
    
    # Likelihood: ordered logistic regression
    y_obs = pm.OrderedLogistic('y_obs', eta=eta, cutpoints=cutpoints, 
                               compute_p=False, observed=y)

# %%
with interaction_model:
    idata = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [intercept, mu_gen_year, sigma_gen_year, beta_gen_year, cutpoints]
# Output()
# /home/downey/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pytensor/compile/function/types.py:970: RuntimeWarning: invalid value encountered in accumulate
#   self.vm()
# /home/downey/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pytensor/compile/function/types.py:970: RuntimeWarning: invalid value encountered in accumulate
#   self.vm()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 2
#       1 with interaction_model:
# ----> 2     idata = pm.sample()
#
# File ~/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pymc/sampling/mcmc.py:871, in sample(draws, tune, chains, cores, random_seed, progressbar, progressbar_theme, step, var_names, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, blas_cores, model, **kwargs)
#     867 t_sampling = time.time() - t_start
#     869 # Packaging, validating and returning the result was extracted
#     870 # into a function to make it easier to test and refactor.
# --> 871 return _sample_return(
#     872     run=run,
#     873     traces=traces,
#     874     tune=tune,
#     875     t_sampling=t_sampling,
#     876     discard_tuned_samples=discard_tuned_samples,
#     877     compute_convergence_checks=compute_convergence_checks,
#     878     return_inferencedata=return_inferencedata,
#     879     keep_warning_stat=keep_warning_stat,
#     880     idata_kwargs=idata_kwargs or {},
#     881     model=model,
#     882 )
#
# File ~/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pymc/sampling/mcmc.py:902, in _sample_return(run, traces, tune, t_sampling, discard_tuned_samples, compute_convergence_checks, return_inferencedata, keep_warning_stat, idata_kwargs, model)
#     900 # Pick and slice chains to keep the maximum number of samples
#     901 if discard_tuned_samples:
# --> 902     traces, length = _choose_chains(traces, tune)
#     903 else:
#     904     traces, length = _choose_chains(traces, 0)
#
# File ~/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pymc/backends/base.py:593, in _choose_chains(traces, tune)
#     591 lengths = [max(0, len(trace) - tune) for trace in traces]
#     592 if not sum(lengths):
# --> 593     raise ValueError("Not enough samples to build a trace.")
#     595 idxs = np.argsort(lengths)
#     596 l_sort = np.array(lengths)[idxs]
#
# ValueError: Not enough samples to build a trace.

# %%
pm.summary(idata)
# Out:
#                        mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# intercept            -0.265  1.365  -2.866    2.341      0.326    0.235
# mu_gen_year          -0.131  0.960  -1.951    1.290      0.459    0.349
# beta_gen_year[0, 0]  -0.025  0.981  -1.874    1.684      0.460    0.349
# beta_gen_year[0, 1]  -0.018  0.987  -1.911    1.644      0.460    0.348
# beta_gen_year[0, 2]  -0.127  0.996  -2.057    1.536      0.461    0.349
# ...                     ...    ...     ...      ...        ...      ...
# beta_gen_year[33, 4]  0.093  0.980  -1.904    1.613      0.458    0.347
# beta_gen_year[33, 5] -0.132  0.998  -2.036    1.585      0.457    0.346
# sigma_gen_year        0.276  0.041   0.202    0.355      0.003    0.002
# cutpoints[0]         -1.216  1.210  -3.564    0.923      0.048    0.034
# cutpoints[1]          1.537  1.208  -0.787    3.707      0.048    0.034
#
#                       ess_bulk  ess_tail  r_hat
# intercept                 18.0     165.0   1.17
# mu_gen_year                5.0      11.0   2.93
# beta_gen_year[0, 0]        5.0      11.0   2.61
# beta_gen_year[0, 1]        5.0      12.0   2.51
# beta_gen_year[0, 2]        5.0      11.0   2.46
# ...                        ...       ...    ...
# beta_gen_year[33, 4]       5.0      11.0   2.56
# beta_gen_year[33, 5]       5.0      11.0   2.31
# sigma_gen_year           199.0     381.0   1.01
# cutpoints[0]             631.0    1129.0   1.02
# cutpoints[1]             647.0    1134.0   1.02
#
# [209 rows x 9 columns]

# %%
import arviz as az

az.to_netcdf(idata, "interaction_model.nc")
# Out:
# 'ordered_logistic_model_idata.nc'

# %%
# !ls -lh interaction_model.nc
# Out:
# -rw-rw-r-- 1 downey downey 3.3M Aug 29 20:32 ordered_logistic_model_idata.nc

# %%
idata = az.from_netcdf("interaction_model.nc")

# %% [markdown]
# ## Model 4
#
# Hierarchical interaction model

# %%
with pm.Model() as hierarchical_model:
    
    # Priors for the global intercept
    intercept = pm.Normal('intercept', mu=0, sigma=2)
    
    # Top-level: Hyperpriors for the year-level effects
    mu_year = pm.Normal('mu_year', mu=0, sigma=2)
    sigma_year = pm.HalfNormal('sigma_year', sigma=2)
    beta_year = pm.Normal('beta_year', mu=mu_year, sigma=sigma_year, shape=len(year_labels))
    
    # Second-level: Hyperpriors for generation effects within each year
    mu_gen = pm.Normal('mu_gen', mu=0, sigma=2, shape=len(year_labels))
    sigma_gen = pm.HalfNormal('sigma_gen', sigma=2, shape=len(year_labels))
    beta_gen = pm.Normal('beta_gen', mu=mu_gen[:, None], sigma=sigma_gen[:, None], 
                         shape=(len(year_labels), len(generation_labels)))
    
    # Priors for the cutpoints (thresholds) between categories
    cutpoints = pm.Normal('cutpoints', mu=np.array([-1, 1]), sigma=2, shape=2,
                          transform=pm.distributions.transforms.ordered)
    
    # Linear combination of coefficients and independent variables
    eta = intercept + beta_year[year_codes] + beta_gen[year_codes, generation_codes]
    
    # Likelihood: ordered logistic regression
    y_obs = pm.OrderedLogistic('y_obs', eta=eta, cutpoints=cutpoints, 
                               compute_p=False, observed=y)

# %%
with hierarchical_model:
    idata = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [intercept, mu_year, sigma_year, beta_year, mu_gen, sigma_gen, beta_gen, cutpoints]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[128], line 2
#       1 with hierarchical_model:
# ----> 2     idata = pm.sample()
#
# File ~/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pymc/sampling/mcmc.py:871, in sample(draws, tune, chains, cores, random_seed, progressbar, progressbar_theme, step, var_names, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, blas_cores, model, **kwargs)
#     867 t_sampling = time.time() - t_start
#     869 # Packaging, validating and returning the result was extracted
#     870 # into a function to make it easier to test and refactor.
# --> 871 return _sample_return(
#     872     run=run,
#     873     traces=traces,
#     874     tune=tune,
#     875     t_sampling=t_sampling,
#     876     discard_tuned_samples=discard_tuned_samples,
#     877     compute_convergence_checks=compute_convergence_checks,
#     878     return_inferencedata=return_inferencedata,
#     879     keep_warning_stat=keep_warning_stat,
#     880     idata_kwargs=idata_kwargs or {},
#     881     model=model,
#     882 )
#
# File ~/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pymc/sampling/mcmc.py:902, in _sample_return(run, traces, tune, t_sampling, discard_tuned_samples, compute_convergence_checks, return_inferencedata, keep_warning_stat, idata_kwargs, model)
#     900 # Pick and slice chains to keep the maximum number of samples
#     901 if discard_tuned_samples:
# --> 902     traces, length = _choose_chains(traces, tune)
#     903 else:
#     904     traces, length = _choose_chains(traces, 0)
#
# File ~/miniconda3/envs/SurveyDataPyMC/lib/python3.12/site-packages/pymc/backends/base.py:593, in _choose_chains(traces, tune)
#     591 lengths = [max(0, len(trace) - tune) for trace in traces]
#     592 if not sum(lengths):
# --> 593     raise ValueError("Not enough samples to build a trace.")
#     595 idxs = np.argsort(lengths)
#     596 l_sort = np.array(lengths)[idxs]
#
# ValueError: Not enough samples to build a trace.

# %%
pm.summary(idata)

# %%
import arviz as az

az.to_netcdf(idata, "hierarchical_model.nc")
# Out:
# 'ordered_logistic_model_idata.nc'

# %%
# !ls -lh hierarchical_model.nc
# Out:
# -rw-rw-r-- 1 downey downey 3.3M Aug 29 20:32 ordered_logistic_model_idata.nc

# %%
idata = az.from_netcdf("hierarchical_model.nc")
